# %% [markdown]
# <a href="https://colab.research.google.com/github/maumaudonut/BINA-Projekt-FS25-Donat/blob/main/Erstes%20Projekt%20Donat/Erstes_BI_Projekt_Donat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Out:
# Running cells with '.venv (Python 3.12.3)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Donat/OneDrive - Berner Fachhochschule/2.Semester/01_BINA/00_Github/MSc_WI_BINA/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# pip install psutil

# %%
url= 'https://github.com/maumaudonut/BINA-Projekt-FS25-Donat/raw/refs/heads/main/Erstes%20Projekt%20Donat/Superstore.csv'

# %%
df = pd.read_csv(url, encoding='Windows-1252')

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# Seltenstes Produkt
# Zähle die Häufigkeit jedes Produkts
product_counts = df['Product Name'].value_counts()

# Finde das Produkt mit der geringsten Häufigkeit
least_sold_product = product_counts.idxmin()
least_sold_count = product_counts.min()

# Ausgabe des Ergebnisses
print(f"Das am seltensten verkaufte Produkt ist: {least_sold_product}")
print(f"Es wurde {least_sold_count} Mal verkauft.")
# Out:
# Das am seltensten verkaufte Produkt ist: Brother MFC-9340CDW LED All-In-One Printer, Copier Scanner
# Es wurde 1 Mal verkauft.

# %%
#Meist verkauftes Produkt

# Zähle die Häufigkeit jedes Produkts
product_counts = df['Product Name'].value_counts()

# Finde das Produkt mit der meisten Häufigkeit
most_sold_product = product_counts.idxmax()
most_sold_count = product_counts.max()

# Ausgabe des Ergebnisses
print(f"Das am meisten verkaufte Produkt ist: {most_sold_product}")
print(f"Es wurde {most_sold_count} Mal verkauft.")
# Out:
# Das am meisten verkaufte Produkt ist: Staple envelope
# Es wurde 48 Mal verkauft.

# %%
#Top 10 Bundesstaaten nach Gesamtverkäufe
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Gruppiere die Daten nach Bundesstaat (State) und summiere die Verkäufe
state_sales = df.groupby('State')['Sales'].sum()

# Sortiere die Bundesstaaten nach den Gesamtverkäufen (absteigend) und wähle die Top 10 aus
top_states = state_sales.sort_values(ascending=False).head(10).reset_index()

# Seaborn-Balkendiagramm erstellen
plt.figure(figsize=(10, 6))  # Größe des Diagramms
sns.barplot(x='State', y='Sales', data=top_states, palette='viridis')  # Balkendiagramm
plt.title('Top 10 Bundesstaaten nach Gesamtverkäufen', fontsize=16)  # Titel
plt.xlabel('Bundesstaat', fontsize=14)  # X-Achsenbeschriftung
plt.ylabel('Gesamtverkäufe', fontsize=14)  # Y-Achsenbeschriftung
plt.xticks(rotation=45)  # Drehe die Bundesstaatenbezeichnungen für bessere Lesbarkeit
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Gitterlinien für die Y-Achse
plt.tight_layout()  # Bessere Anpassung des Layouts
plt.show()  # Diagramm anzeigen
# Out:
# <ipython-input-9-17c5be4cb628>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='State', y='Sales', data=top_states, palette='viridis')  # Balkendiagramm

# %%
# Preis pro Stück berechnen
df['Price per Unit'] = df['Sales'] / df['Quantity']

# Ergebnis anzeigen
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
# Gruppiere die Daten nach Bundesstaat (State) und summiere die Verkäufe
state_sales = df.groupby('State')['Sales'].sum()

# Sortiere die Bundesstaaten nach den Gesamtverkäufen (absteigend)
sorted_states = state_sales.sort_values(ascending=False)

# Top 10 Bundesstaaten auswählen
top_states = sorted_states.head(10)

# Summe der Verkäufe der restlichen Bundesstaaten berechnen
other_sales = sorted_states[10:].sum()

# "Other States" zur Top-10-Liste hinzufügen
top_states['Other States'] = other_sales

# Kuchendiagramm erstellen
plt.figure(figsize=(8, 8))  # Größe des Diagramms
plt.pie(
    top_states,  # Werte für das Kuchendiagramm
    labels=top_states.index,  # Beschriftungen für die Segmente
    autopct='%1.1f%%',  # Prozentangaben anzeigen (1 Nachkommastelle)
    startangle=140,  # Startwinkel für das erste Segment
    colors=plt.cm.tab20.colors,  # Farbpalette
    wedgeprops={'edgecolor': 'white', 'linewidth': 1}  # Weiße Trennlinien zwischen den Segmenten
)

# Titel hinzufügen
plt.title('Top 10 Bundesstaaten nach Gesamtverkäufen (inkl. Other States)', fontsize=16, pad=20)

# Diagramm anzeigen
plt.tight_layout()
plt.show()
